# %% [markdown]
# <a href="https://colab.research.google.com/github/tleung3334/beginning-bioinformatics/blob/main/MAFFT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install MAFFT and TrimAl

# %%
#Install MAFFT from built in repo
# !apt-get -qq install mafft
# !mafft --version
# Out:
# Extracting templates from packages: 100%
# Selecting previously unselected package fonts-lato.
# (Reading database ... 122809 files and directories currently installed.)
# Preparing to unpack .../00-fonts-lato_2.015-1_all.deb ...
# Unpacking fonts-lato (2.015-1) ...
# Selecting previously unselected package libclone-perl:amd64.
# Preparing to unpack .../01-libclone-perl_0.46-1build3_amd64.deb ...
# Unpacking libclone-perl:amd64 (0.46-1build3) ...
# Selecting previously unselected package libdata-dump-perl.
# Preparing to unpack .../02-libdata-dump-perl_1.25-1_all.deb ...
# Unpacking libdata-dump-perl (1.25-1) ...
# Selecting previously unselected package libencode-locale-perl.
# Preparing to unpack .../03-libencode-locale-perl_1.05-3_all.deb ...
# Unpacking libencode-locale-perl (1.05-3) ...
# Selecting previously unselected package libhttp-date-perl.
# Preparing to unpack .../04-libhttp-date-perl_6.06-1ubuntu0.24.04.1_all.deb ...
# ...

# %%
#Install TrimAl from author's github repo and unzip
# !wget -q https://github.com/inab/trimal/releases/download/v1.5.0/trimAl_Linux_x86-64.zip
# !unzip -q trimAl_Linux_x86-64.zip

#Move trimal to PATH location for easier use then cleanup files we don't need
# !mv trimAl_Linux_x86-64/trimal /usr/local/bin
# !rm trimAl_Linux_x86-64.zip
# !rm -rf trimAl_Linux_x86-64

# %%
# install biopython
# !pip -q install biopython pillow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 34.3 MB/s eta 0:00:00

# %%
#Check installs worked by getting version info
# !mafft --version
# !trimal --version
import Bio
print (Bio.__version__)
# Out:
# v7.505 (2022/Apr/10)
#
# trimAl v1.5.rev0 build[2024-05-27]
#
# 1.88

# %%
# !pip install biopython
# !sudo apt-get -qq update
# !sudo apt-get -qq install mafft
# Out:
# ...
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu noble InRelease' does not seem to provide it (sources.list entry misspelt?)

# %% [markdown]
# #Run MAFFT in auto mode
# * **Assumes you have uploaded the P450.fasta file to this Runtime**
# * MAFFT manual: https://mafft.cbrc.jp/alignment/software/manual/manual.html

# %%
# run mafft in auto mode (let mafft decided the optimal algorithm for given dataset)
# !mafft --auto P450.fasta > P450_aln.fasta
# Out:
# /usr/bin/mafft: Cannot open P450.fasta.
#
# /usr/bin/mafft: line 1270: /tmp/mafft.R80UDiod6K/infile: No such file or directory
# awk: cannot open "/tmp/mafft.R80UDiod6K/size" (No such file or directory)
# awk: cannot open "/tmp/mafft.R80UDiod6K/size" (No such file or directory)
# /usr/bin/mafft: line 1274: [: too many arguments
# /usr/bin/mafft: line 1279: [: too many arguments
# /usr/bin/mafft: line 1284: [: too many arguments
# /usr/bin/mafft: line 1289: [: -lt: unary operator expected
# /usr/bin/mafft: line 1294: [: -lt: unary operator expected
# /usr/bin/mafft: line 1301: [: -lt: unary operator expected
# /usr/bin/mafft: line 1308: [: -lt: unary operator expected
# ------------------------------------------------------------------------------
#   MAFFT v7.505 (2022/Apr/10)
#   https://mafft.cbrc.jp/alignment/software/
#   MBE 30:772-780 (2013), NAR 30:3059-3066 (2002)
# ------------------------------------------------------------------------------
# High speed:
# ...

# %%
# !mafft --auto P450.fasta > P450_MAFFT_aligned.fasta
# Out:
# /usr/bin/mafft: Cannot open P450.fasta.
#
# /usr/bin/mafft: line 1270: /tmp/mafft.81yJZGWFs3/infile: No such file or directory
# awk: cannot open "/tmp/mafft.81yJZGWFs3/size" (No such file or directory)
# awk: cannot open "/tmp/mafft.81yJZGWFs3/size" (No such file or directory)
# /usr/bin/mafft: line 1274: [: too many arguments
# /usr/bin/mafft: line 1279: [: too many arguments
# /usr/bin/mafft: line 1284: [: too many arguments
# /usr/bin/mafft: line 1289: [: -lt: unary operator expected
# /usr/bin/mafft: line 1294: [: -lt: unary operator expected
# /usr/bin/mafft: line 1301: [: -lt: unary operator expected
# /usr/bin/mafft: line 1308: [: -lt: unary operator expected
# ------------------------------------------------------------------------------
#   MAFFT v7.505 (2022/Apr/10)
#   https://mafft.cbrc.jp/alignment/software/
#   MBE 30:772-780 (2013), NAR 30:3059-3066 (2002)
# ------------------------------------------------------------------------------
# High speed:
# ...

# %%
# !ls
# Out:
# P450_aln.fasta	P450_MAFFT_aligned.fasta  sample_data

# %%
# !ls -lh
# Out:
# total 4.0K
# -rw-r--r-- 1 root root    0 Sep 18 20:15 P450_aln.fasta
# -rw-r--r-- 1 root root    0 Sep 18 20:25 P450_MAFFT_aligned.fasta
# drwxr-xr-x 1 root root 4.0K Sep 18 20:14 sample_data

# %%
# !find /content -name "P450.fasta" -ls
# Out:
#   4986314     80 -rw-r--r--   1 root     root        78412 Sep 18 20:14 /content/sample_data/P450.fasta

# %%
# !ls -lh /content/sample_data/P450.fasta
# Out:
# -rw-r--r-- 1 root root 77K Sep 18 20:14 /content/sample_data/P450.fasta

# %%
# !mafft --auto /content/sample_data/P450.fasta > /content/P450_MAFFT_aligned.fasta
# Out:
# nthread = 0
# nthreadpair = 0
# nthreadtb = 0
# ppenalty_ex = 0
# stacksize: 8192 kb
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
#
#
#
# Making a distance matrix ..
#
# There are 8 ambiguous characters.
#   101 / 129
# done.
#
# Constructing a UPGMA tree (efffree=0) ...
#   120 / 129
# done.
#
# Progressive alignment 1/2...
# STEP   114 / 128  f
# Reallocating..done. *alloclen = 4930
# STEP   128 / 128  f
# done.
#
# Making a distance matrix from msa..
#   100 / 129
# done.
#
# Constructing a UPGMA tree (efffree=1) ...
#   120 / 129
# done.
#
# Progressive alignment 2/2...
# STEP   119 / 128  f
# Reallocating..done. *alloclen = 4275
# STEP   128 / 128  f
# done.
#
# disttbfast (aa) Version 7.505
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 0 thread(s)
#
# rescale = 1
# dndpre (aa) Version 7.505
# alg=X, model=BLOSUM62, 1.53, +0.12, -0.00, noshift, amax=0.0
# 0 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 0
# ...

# %%
# !ls -lh /content/P450_MAFFT_aligned.fasta
# Out:
# -rw-r--r-- 1 root root 378K Sep 18 20:34 /content/P450_MAFFT_aligned.fasta

# %%
# !head /content/P450_MAFFT_aligned.fasta
# Out:
# >gi|33113212|gb|AAP94192.1| cytochrome P450 monooxygenase [Tribolium castaneum]
# ------------------------------------------------------------
# ---------MLVLTTVLT------------------------------AAA---------
# -------------------------------------VFL-LFY---------LFYC-YK
# TIK---------------------------------------------------------
# -------------------QHI--------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
